# %% [markdown]
# <a href="https://colab.research.google.com/github/HiteshAdari/KKBOX_music_rec/blob/main/kkbox_music_rec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option("display.max_columns", 120)
pd.set_option("display.max_rows", 120)

# %%
import opendatasets as od

# %%
od.download('https://www.kaggle.com/competitions/kkbox-music-recommendation-challenge')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: hiteshadari
# Your Kaggle Key: ··········
# ...
# 100%|██████████| 345M/345M [00:03<00:00, 110MB/s]
# Extracting archive ./kkbox-music-recommendation-challenge/kkbox-music-recommendation-challenge.zip to ./kkbox-music-recommendation-challenge

# %%
import os

# %%
os.listdir('kkbox-music-recommendation-challenge')
# Out:
# ['sample_submission.csv.7z',
#  'test.csv.7z',
#  'song_extra_info.csv.7z',
#  'members.csv.7z',
#  'train.csv.7z',
#  'songs.csv.7z']

# %%
# !p7zip -d '/content/kkbox-music-recommendation-challenge/members.csv.7z'
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 1349856 bytes (1319 KiB)
#
# Extracting archive: /content/kkbox-music-recommendation-challenge/members.csv.7z
# --
# Path = /content/kkbox-music-recommendation-challenge/members.csv.7z
# Type = 7z
# Physical Size = 1349856
# Headers Size = 130
# Method = LZMA2:3m
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       2503827
# Compressed: 1349856

# %%
# !p7zip -d '/content/kkbox-music-recommendation-challenge/sample_submission.csv.7z'
# !p7zip -d '/content/kkbox-music-recommendation-challenge/song_extra_info.csv.7z'
# !p7zip -d '/content/kkbox-music-recommendation-challenge/songs.csv.7z'
# !p7zip -d '/content/kkbox-music-recommendation-challenge/test.csv.7z'
# !p7zip -d '/content/kkbox-music-recommendation-challenge/train.csv.7z'
# Out:
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 463688 bytes (453 KiB)
#
# Extracting archive: /content/kkbox-music-recommendation-challenge/sample_submission.csv.7z
# --
# Path = /content/kkbox-music-recommendation-challenge/sample_submission.csv.7z
# Type = 7z
# Physical Size = 463688
# Headers Size = 146
# Method = LZMA2:24
# Solid = -
# Blocks = 1
#
# Everything is Ok
#
# Size:       29570380
# Compressed: 463688
#
# 7-Zip (a) [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 103608205 bytes (99 MiB)
#
# Extracting archive: /content/kkbox-music-recommendation-challenge/song_extra_info.csv.7z
# --
# ...

# %%
members = pd.read_csv('/content/members.csv')
members.head(5)
# Out:
#                                            msno  city  bd gender  \
# 0  XQxgAYj3klVKjR3oxPPXYYFp4soD4TuBghkhMTD4oTw=     1   0    NaN
# 1  UizsfmJb9mV54qE9hCYyU07Va97c0lCRLEQX3ae+ztM=     1   0    NaN
# 2  D8nEhsIOBSoE6VthTaqDX8U6lqjJ7dLdr72mOyLya2A=     1   0    NaN
# 3  mCuD+tZ1hERA/o5GPqk38e041J8ZsBaLcu7nGoIIvhI=     1   0    NaN
# 4  q4HRBfVSssAFS9iRfxWrohxuk9kCYMKjHOEagUMV6rQ=     1   0    NaN
#
#    registered_via  registration_init_time  expiration_date
# 0               7                20110820         20170920
# 1               7                20150628         20170622
# 2               4                20160411         20170712
# 3               9                20150906         20150907
# 4               4                20170126         20170613

# %%
songExtraInfo = pd.read_csv('song_extra_info.csv')
songExtraInfo.head(5)
# Out:
#                                         song_id             name          isrc
# 0  LP7pLJoJFBvyuUwvu+oLzjT+bI+UeBPURCecJsX1jjs=               我們  TWUM71200043
# 1  ClazTFnk6r0Bnuie44bocdNMM3rdlrq0bCGAsGUWcHE=  Let Me Love You  QMZSY1600015
# 2  u2ja/bZE3zhCGxvbbOB3zOoUjx27u40cf5g09UXMoKQ=              原諒我  TWA530887303
# 3  92Fqsy0+p6+RHe2EoLKjHahORHR1Kq1TBJoClW9v+Ts=          Classic  USSM11301446
# 4  0QFmz/+rJy1Q56C1DuYqT9hKKqi5TUqx0sN0IwvoHrw=             愛投羅網  TWA471306001

# %%
songs = pd.read_csv('songs.csv')
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
train.head(5)
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# ...

# %%
songs.head(5)
# Out:
#                                         song_id  song_length genre_ids  \
# 0  CXoTN1eb7AI+DntdU1vbcwGRV4SCIDxZu+YD8JP8r4E=       247640       465
# 1  o0kFgae9QtnYgRkVPqLJwa05zIhRlUjfF7O1tDw0ZDU=       197328       444
# 2  DwVvVurfpuz+XPuFvucclVQEyPqcpUkHR0ne1RQzPs0=       231781       465
# 3  dKMBWoZyScdxSkihKG+Vf47nc18N9q4m58+b4e7dSSE=       273554       465
# 4  W3bqWd3T+VeHFzHAUfARgW9AvVRaF4N5Yzm4Mr6Eo/o=       140329       726
#
#         artist_name                            composer     lyricist  language
# 0  張信哲 (Jeff Chang)                                  董貞          何啟弘       3.0
# 1         BLACKPINK  TEDDY|  FUTURE BOUNCE|  Bekuh BOOM        TEDDY      31.0
# 2      SUPER JUNIOR                                 NaN          NaN      31.0
# 3             S.H.E                                 湯小康          徐世珍       3.0
# 4              貴族精選                         Traditional  Traditional      52.0

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7377418 entries, 0 to 7377417
# Data columns (total 6 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   msno                object
#  1   song_id             object
#  2   source_system_tab   object
#  3   source_screen_name  object
#  4   source_type         object
#  5   target              int64
# dtypes: int64(1), object(5)
# memory usage: 337.7+ MB

# %%
songs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296320 entries, 0 to 2296319
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   song_id      object
#  1   song_length  int64
#  2   genre_ids    object
#  3   artist_name  object
#  4   composer     object
#  5   lyricist     object
#  6   language     float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 122.6+ MB
